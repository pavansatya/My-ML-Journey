# %%
import pandas as pd 
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('placement.csv')
df.head()
# Out:
#    cgpa  package
# 0  6.89     3.26
# 1  5.12     1.98
# 2  7.82     3.25
# 3  7.42     3.67
# 4  6.94     3.57

# %%
plt.scatter(x='cgpa', y='package', data=df)
plt.xlabel('CGPA')
plt.ylabel('Package')
plt.title('CGPA vs Package')
# Out:
# Text(0.5, 1.0, 'CGPA vs Package')

# %%
X = df.cgpa.values.reshape(-1, 1)
y = df.package.values

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=25)

# %%
model = LinearRegression()
model.fit(X_train, y_train)
y_pred = model.predict(X_test)

# %%
model.predict([[9.5]])
# Out:
# array([4.36869344])

# %%
plt.scatter(df['cgpa'], df['package'])
plt.plot(X_test, y_pred, color='red')
plt.xlabel('CGPA')
plt.ylabel('Package')
plt.title('CGPA vs Package with Regression Line')
# Out:
# Text(0.5, 1.0, 'CGPA vs Package with Regression Line')

# %%
m = model.coef_
b = model.intercept_

# %%
m, b
# Out:
# (array([0.55141106]), -0.8697116297945922)

# %%
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
print("Mean Squared Error:", mean_squared_error(y_test, y_pred))
print("R-squared:", r2_score(y_test, y_pred))
print("Mean Absolute Error:", mean_absolute_error(y_test, y_pred))
# Out:
# Mean Squared Error: 0.11094145072760585
# R-squared: 0.8214057225024336
# Mean Absolute Error: 0.27140596198472106
